# %%
# !pip install google-cloud-vision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.4/466.4 kB 9.2 MB/s eta 0:00:00
# ...

# %%
import os

# Replace 'your-key-file.json' with the actual filename
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/youeee-0b2314b487e8.json"

# %%
import io
import os
from google.cloud import vision

def detect_text(image_path):
    """Detects text in an image."""
    client = vision.ImageAnnotatorClient()

    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    if response.error.message:
        raise Exception(f"{response.error.message}")

    return texts

def parse_texts(texts):
    ingredients = ""
    nutrition_facts = ""
    is_ingredient_section = False
    is_nutrition_section = False

    for text in texts[1:]:  # Skip the first element which is the entire text
        description = text.description

        if "Ingredients" in description:
            is_ingredient_section = True
            is_nutrition_section = False
        elif "Nutrition Facts" in description:
            is_nutrition_section = True
            is_ingredient_section = False

        if is_ingredient_section:
            ingredients += " " + description
        elif is_nutrition_section:
            nutrition_facts += " " + description

    return ingredients, nutrition_facts

# Ensure your JSON key file path is set correctly
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/youeee-0b2314b487e8.json"

image_path = '/content/your-image.jpg'  # Replace with the path to your uploaded image file
texts = detect_text(image_path)

ingredients, nutrition_facts = parse_texts(texts)
print("Ingredients:", ingredients)
print("Nutrition Facts:", nutrition_facts)
# Out:
# Ingredients:
# Nutrition Facts:

# %%
import io
import os
from google.cloud import vision

def detect_text(image_path):
    """Detects text in an image."""
    client = vision.ImageAnnotatorClient()

    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    if response.error.message:
        raise Exception(f"{response.error.message}")

    return texts

def parse_texts(texts):
    ingredients = ""
    nutrition_facts = ""
    is_ingredient_section = False
    is_nutrition_section = False

    print("Detected texts:")
    for text in texts:
        print(text.description)  # Print each detected text

    for text in texts[1:]:  # Skip the first element which is the entire text
        description = text.description

        if "Ingredients" in description:
            is_ingredient_section = True
            is_nutrition_section = False
        elif "Nutrition Facts" in description:
            is_nutrition_section = True
            is_ingredient_section = False

        if is_ingredient_section:
            ingredients += " " + description
        elif is_nutrition_section:
            nutrition_facts += " " + description

    return ingredients, nutrition_facts

# Ensure your JSON key file path is set correctly
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/youeee-0b2314b487e8.json"


image_path = '/content/your-image.jpg'  # Replace with the path to your uploaded image file
texts = detect_text(image_path)

if not texts:
    print("No text detected.")
else:
    ingredients, nutrition_facts = parse_texts(texts)
    print("Ingredients:", ingredients)
    print("Nutrition Facts:", nutrition_facts)
# Out:
# Detected texts:
# Kurkure is a Registered Trade Mark of PepsiCo, Inc.
# MFD. BY: For manufacturer's details, see first two characters of
# batch no, and see below.
# N1-PepsiCo India Holdings Pvt. Ltd., Lic. No. 10012063000110.
# N2-PepsiCo India Holdings Pvt. Ltd, Lic. No. 10012022000339.
# N3-PepsiCo India Holdings Pvt. Ltd, Lic. No.10012031000120.
# DF-Daawat Foods Ltd, Lic. No. 10012064000072.
# HB-Heemankshi Bakers Pvt. Ltd., Lic. No. 10014047000100.
# AB-AFP Manufacturing Co. Pvt. Ltd., Lic. No. 10016033000284.
# JD M/S JDB STEEL LLP, Lic. No. 10017071000922.
# GN-Geo Nutri Foods Pvt. Ltd., Lic. No. 10015031001657.
# BI-Badshah International Pvt. Ltd., Lic. No. 10015051001429.
# AF-Ameya Foods, Lic. No. 11221999000261.
# RP-Vadit Snacks Pvt. Ltd., Lic. No. 10521999000044.
# PROPRIETARY FOOD-NAMKEEN (15.1)
# INGREDIENTS: Cereal Products (57%) (Rice Meal (38%), Com
# Meal (19%), Edible Vegetable Oil (Palmclein), "Seasoning
# ("Spices & Condiments, Sugar, lodised Salt, Acidity
# ...

# %%
import io
import os
from google.cloud import vision

def detect_text(image_path):
    """Detects text in an image."""
    client = vision.ImageAnnotatorClient()

    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    if response.error.message:
        raise Exception(f"{response.error.message}")

    return texts

def parse_texts(texts):
    ingredients = ""
    nutrition_facts = ""
    is_ingredient_section = False
    is_nutrition_section = False

    print("Detected texts:")
    for text in texts:
        print(text.description)  # Print each detected text

    for text in texts[1:]:  # Skip the first element which is the entire text
        description = text.description

        # Check for section headers
        if "Ingredients" in description:
            is_ingredient_section = True
            is_nutrition_section = False
            continue  # Skip this line and continue to the next
        elif "Nutrition Facts" in description:
            is_nutrition_section = True
            is_ingredient_section = False
            continue  # Skip this line and continue to the next

        # Collect text for each section
        if is_ingredient_section:
            ingredients += " " + description
        elif is_nutrition_section:
            nutrition_facts += " " + description

    return ingredients, nutrition_facts

# Ensure your JSON key file path is set correctly
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/youeee-0b2314b487e8.json"

image_path = '/content/your-image.jpg'  # Replace with the path to your uploaded image file
texts = detect_text(image_path)

if not texts:
    print("No text detected.")
else:
    ingredients, nutrition_facts = parse_texts(texts)
    print("\nExtracted Ingredients:", ingredients.strip())
    print("\nExtracted Nutrition Facts:", nutrition_facts.strip())
# Out:
# Detected texts:
# Kurkure is a Registered Trade Mark of PepsiCo, Inc.
# MFD. BY: For manufacturer's details, see first two characters of
# batch no, and see below.
# N1-PepsiCo India Holdings Pvt. Ltd., Lic. No. 10012063000110.
# N2-PepsiCo India Holdings Pvt. Ltd, Lic. No. 10012022000339.
# N3-PepsiCo India Holdings Pvt. Ltd, Lic. No.10012031000120.
# DF-Daawat Foods Ltd, Lic. No. 10012064000072.
# HB-Heemankshi Bakers Pvt. Ltd., Lic. No. 10014047000100.
# AB-AFP Manufacturing Co. Pvt. Ltd., Lic. No. 10016033000284.
# JD M/S JDB STEEL LLP, Lic. No. 10017071000922.
# GN-Geo Nutri Foods Pvt. Ltd., Lic. No. 10015031001657.
# BI-Badshah International Pvt. Ltd., Lic. No. 10015051001429.
# AF-Ameya Foods, Lic. No. 11221999000261.
# RP-Vadit Snacks Pvt. Ltd., Lic. No. 10521999000044.
# PROPRIETARY FOOD-NAMKEEN (15.1)
# INGREDIENTS: Cereal Products (57%) (Rice Meal (38%), Com
# Meal (19%), Edible Vegetable Oil (Palmclein), "Seasoning
# ("Spices & Condiments, Sugar, lodised Salt, Acidity
# ...

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
import io
import os
from google.cloud import vision
import openai
from openai import OpenAI

# Set up OpenAI API key
#openai.api_key = 'sk-proj-AEeYkadsKbGCbNSY3czNT3BlbkFJZ7BrLkftJygyHVOYB5sJ'  # Replace with your actual OpenAI API key
client = OpenAI(api_key='*******')
#response = (...)

def detect_text(image_path):
    """Detects text in an image."""
    client = vision.ImageAnnotatorClient()

    with io.open(image_path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    if response.error.message:
        raise Exception(f"{response.error.message}")

    return texts

def parse_with_llm(texts):
    combined_text = " ".join([text.description for text in texts])

    prompt = f"""
    Extract the product name, barcode number, ingredients, and nutrition facts from the following text:

    {combined_text}

    Provide the information in the following JSON format:
    {{
        "product_name": "name of the product",
        "barcode_number": "barcode number",
        "ingredients": "list of ingredients",
        "nutrition_facts": "list of nutrition facts"
    }}
    """

    response = client.chat.completions.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=500
    )

    return response.choices[0].message.content.strip()

# Ensure your JSON key file path is set correctly
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/youeee-0b2314b487e8.json"

image_path = '/content/your-image.jpg'  # Replace with the path to your uploaded image file
texts = detect_text(image_path)

if not texts:
    print("No text detected.")
else:
    structured_info = parse_with_llm(texts)
    print(structured_info)
# Out:
# {
#         "product_name": "Kurkure",
#         "barcode_number": "8901491363020",
#         "ingredients": "Cereal Products (57%) (Rice Meal (38%), Com Meal (19%), Edible Vegetable Oil (Palmclein), Seasoning (Spices & Condiments, Sugar, lodised Salt, Acidity Regulators (330, 296), Flavour (Natural and Nature Identical Flavouring Substances), Flavour Enhancers (627,631), Edible Vegetable Oil (Com Oil), Color (160c), Emulsifier (414)), Gram Meal (6%). Contains Onion and Garlic",
#         "nutrition_facts": {
#             "serve_size": "20g",
#             "energy_per_100g": "558 kcal",
#             "ada_per_serve": "6%",
#             "protein": "5.69",
#             "carbohydrate": "56.29",
#             "total_sugars": "2.09",
#             "added_sugar": "179",
#             "total_fat": "34.59",
#             "saturated_fat": "15.59",
#             "trans_fat": "0.19",
#             "sodium": "680 mg"
#         }
#      }
